# %% [markdown]
# <a href="https://colab.research.google.com/github/HuynhQuocDan/Artificial-Intelligence/blob/main/week12_MTCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mtcnn
import matplotlib.pyplot as plt
from mtcnn import MTCNN
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#nhận diện khuôn mặt
filename = '/content/drive/MyDrive/MonHoc_AI/realmarid.jpg'
pixels = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(pixels)
for face in faces:
  print(face)
# Out:
# ...
# 4/4 [==============================] - 0s 28ms/step
# {'box': [295, 170, 39, 50], 'confidence': 0.9999998211860657, 'keypoints': {'left_eye': (307, 188), 'right_eye': (323, 188), 'nose': (316, 200), 'mouth_left': (307, 205), 'mouth_right': (325, 204)}}
# {'box': [157, 162, 37, 52], 'confidence': 0.9999950528144836, 'keypoints': {'left_eye': (167, 182), 'right_eye': (184, 181), 'nose': (176, 192), 'mouth_left': (168, 199), 'mouth_right': (184, 199)}}
# {'box': [439, 177, 37, 51], 'confidence': 0.999943196773529, 'keypoints': {'left_eye': (446, 197), 'right_eye': (464, 197), 'nose': (454, 207), 'mouth_left': (447, 218), 'mouth_right': (461, 218)}}
# {'box': [706, 203, 40, 49], 'confidence': 0.9999306797981262, 'keypoints': {'left_eye': (717, 221), 'right_eye': (736, 221), 'nose': (727, 233), 'mouth_left': (718, 239), 'mouth_right': (736, 238)}}
# ...

# %%
#nhận diễn khuôn mặt
# !pip install mtcnn
import matplotlib.pyplot as plt
from mtcnn import MTCNN
filename = '/content/drive/MyDrive/MonHoc_AI/ando.jpg'
img = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
plt.imshow(img)
ax = plt.gca()
for face in faces:
  x, y, width, height = face['box']
  rect = plt.Rectangle((x,y),width,height,fill =False,color = 'red')
  ax.add_patch(rect)
plt.show()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# 9/9 [==============================] - 1s 46ms/step

# %%
#nhận diễn khuôn mặt
# !pip install mtcnn
import matplotlib.pyplot as plt
from mtcnn import MTCNN
filename = '/content/drive/MyDrive/MonHoc_AI/realmarid.jpg'
img = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
plt.imshow(img)
ax = plt.gca()
i = 0
for face in faces:
  i+= 1
  x, y, width, height = face['box']
  rect = plt.Rectangle((x,y),width,height,fill =False,color = 'orange')
  ax.add_patch(rect)
  for key,value in face ['keypoints'].items():
    dot = plt.Circle(value,radius = 2, color = 'green')
    ax.add_patch(dot)
  
plt.show()
print('so nguoi: ',i)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# 4/4 [==============================] - 0s 31ms/step
# so nguoi:  12

# %%
# !pip install mtcnn
from matplotlib import pyplot
import matplotlib.pyplot as plt
from mtcnn import MTCNN
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#tách ảnh khuôn mặt và lưu

def draw_faces(filename, result_list):
  data = plt.imread(filename)
  for i in range(len(result_list)):
    x1,y1,width,height = result_list[i]['box']
    x2,y2 = x1+width, y1+height
    plt.subplot(1,len(result_list),i+1)
    plt.axis('off')
    plt.imshow(data[y1:y2,x1:x2])
  plt.show()

# %%
filename ='/content/drive/MyDrive/MonHoc_AI/realmarid.jpg'
img = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
draw_faces(filename, faces)
# Out:
# ...
# 4/4 [==============================] - 0s 30ms/step

# %%
from keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input
import numpy as np

model = VGG16(weights='imagenet', include_top=False)

img_path = '/content/drive/MyDrive/MonHoc_AI/koi.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

features = model.predict(x)
# Out:
# 1/1 [==============================] - 1s 506ms/step

# %%
from keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input
import numpy as np
import matplotlib.pyplot as plt
model = VGG16(weights='imagenet', include_top=False)

img_path = '/content/drive/MyDrive/MonHoc_AI/koi.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
plt.imshow(img)
plt.show()
features = model.predict(x)
# Out:
# 1/1 [==============================] - 1s 627ms/step

# %%
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
import numpy as np
model = ResNet50(weights='imagenet')

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions
import numpy as np
model = VGG16(weights='imagenet', include_top=True)
img_path = '/content/drive/MyDrive/MonHoc_AI/tree.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
preds = model.predict(x)
print('Predicted:', decode_predictions(preds, top=3)[0])
#features = model.predict(x)

img = plt.imread(img_path)
plt.imshow(img)
# Out:
# 1/1 [==============================] - 1s 556ms/step
# Predicted: [('n03991062', 'pot', 0.035423003), ('n04417672', 'thatch', 0.027794013), ('n11879895', 'rapeseed', 0.016805671)]
