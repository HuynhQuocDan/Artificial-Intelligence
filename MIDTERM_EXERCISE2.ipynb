# %% [markdown]
# <a href="https://colab.research.google.com/github/HuynhQuocDan/Artificial-Intelligence/blob/main/MIDTERM_EXERCISE2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import listdir
from numpy import asarray
from numpy import save
from keras.utils.image_utils import img_to_array
from keras.utils import load_img

from google.colab import drive
drive.mount('/content/drive')

folder='/content/drive/MyDrive/Colab Notebooks/Money/'

photos,labels = list(),list()

for file in listdir(folder):
  output=0.0
  if file.startswith('500k'):
    output=1.0
  if file.startswith('200k'):
    output=2.0
  if file.startswith('100k'):
    output=3.0
  if file.startswith('50k'):
    output=4.0
  if file.startswith('20k'):
    output=5.0
  if file.startswith('10k'):
    output=6.0
  if file.startswith('5k'):
    output=7.0
  if file.startswith('2k'):
    output=8.0
  if file.startswith('1k'):
    output=9.0
  photo = load_img(folder+file,target_size=(100,100))
  photo = img_to_array(photo)
  photos.append(photo)
  labels.append(output)

photos = asarray(photos)
labels = asarray(labels)
save('/content/drive/MyDrive/Colab Notebooks/photo_money.npy',photos)
save('/content/drive/MyDrive/Colab Notebooks/label_money.npy',labels)

photos.shape

labels.shape

from sklearn.model_selection import train_test_split

train_x, test_x, train_y,  test_y = train_test_split(photos,labels, test_size=0.3, train_size=0.7)

     

train_x.shape

test_x.shape

#train_x = train_x.reshape([700,40,40,3])
train_x = train_x.astype('float32')
train_x = train_x/255

#test_x = test_x.reshape([300, 40, 40, 3])
test_x = test_x.astype('float32')
test_x = test_x/255

from keras.utils import to_categorical
y_train = to_categorical(train_y)
y_test = to_categorical(test_y)

train_x.shape

y_train.shape

from keras import Sequential,Model,Input
from keras.layers import Dense,Flatten,Dropout, Conv2D, MaxPooling2D,Normalization
from keras.optimizers import Adam

batch_size = 100
epochs = 10
classes = 10
model = Sequential()
model.add(Conv2D(32,kernel_size=(3,3),activation='linear',input_shape=(100,100,3),padding='same'))

from keras.layers import LeakyReLU
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D((2,2),padding='same'))

model.add(Conv2D(64,(3,3),activation='linear',padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D((2,2),padding='same'))

model.add(Conv2D(128,(3,3),activation='linear',padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(MaxPooling2D((2,2),padding='same'))

model.add(Flatten())

model.add(Dense(700,activation='linear'))
model.add(Dropout(0.5))
model.add(Dense(classes,activation='softmax'))

model.summary()

from keras.backend import categorical_crossentropy
model.compile(loss='categorical_crossentropy', optimizer=Adam(),metrics =['accuracy'])

train = model.fit(train_x,y_train,batch_size=64,epochs=15,verbose=1)
test_loss, test_acc = model.evaluate(test_x, y_test)
print("Accuracy:", test_acc)
print('Loss:', test_loss)

model.save('/content/drive/MyDrive/Colab Notebooks/Predict_money.h5')

#test mo hinh
from keras.utils import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np
img = load_img('test.jpg',target_size=(100,100,3))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1,100,100,3)
img = img.astype('float32')
img = img/255
a = np.argmax(model.predict(img),axis=-1)
print(a)
if(a == 1):
  print("Đây là 500k")
if (a == 2):
  print("Đây là 200k")
if (a == 3):
  print("Đây là 100k")
if (a == 4):
  print("Đây là 50k")
if (a == 5):
  print("Đây là 20k")
if (a == 6):
  print("Đây là 10k")
if (a == 7):
  print("Đây là 5k")
if (a == 8):
  print("Đây là 2k")
if (a == 9):
  print("Đây là 1k")
